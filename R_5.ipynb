# %%
import networkx as nx
import random

class Uber:
    def __init__(self):
        try:
            self.b = 200
            self.d = 30
            self.e = 5
            self.f = 24
            self.no_of_trips = 0
            self.count = 1
            self.cus_dir = {}
            self.cust_list = []
            self.vechile_list = self.initialize_vehicle_list()
            self.vechile_travelled = self.initialize_vehicle_travelled()
            self.vechile_track = self.initialize_vehicle_track()
            self.curr_vechile_location = self.initialize_curr_location(self.d)
            self.no_of_passengers = self.initialize_passengers(self.d)
            self.vechile_travel_distance = self.initialize_vehicle_distance(self.d)

            a = 1000
            self.G = self.generate_connected_graph(a, self.b, self.d, self.e, self.f)
            weights = None
            self.G = self.add_weights_to_graph(weights, self.G)
            self.total_clock_ticks = self.f * 60


            for self.clock_ticks in range(1, self.total_clock_ticks + 1):
                self.update()
                self.take_ride_requests(self.G)
                self.pick_customers()
                self.drop_customers()

            while any(self.vechile_list[i] for i in range(self.d)):
                self.clock_ticks += 1
                self.update()
                self.pick_customers()
                self.drop_customers()

            print("average distance",self.average_distance())
            print(" ")
            print("average trips",self.average_trips())

        except Exception as e:
            raise e

    def initialize_vehicle_list(self):
        """
        It takes number of vechiles as argument and returns a list where each vechile is intailized their starting position as 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        return [[] for _ in range(self.d)]

    def initialize_vehicle_travelled(self):
        """
        It takes number of vechiles as argument and returns a list where each vechile is intailized their starting position as 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        return [[] for _ in range(self.d)]

    def initialize_vehicle_track(self):
        """
        It takes number of vechiles as argument and return a list where no of passengers in each vechile is intialized to 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        return [[] for _ in range(self.d)]

    def initialize_curr_location(self, d):
        """
          return a list of lists of size equal to no of vechiles
        Returns:
            list of lists
        """
        return [0] * d

    def initialize_passengers(self, d):
        """
        It takes number of vechiles as argument and return a list where vechile travel distance is equal to 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        return [0] * d

    def initialize_vehicle_distance(self, d):
        """
        It takes number of vechiles as argument and return a list where vechile travel distance is equal to 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        return [0] * d
    def GenerateGraph(self,a,b,c,d,e,f):
        """
        This function takes below arguments and returns a Graph object
        Args:
            a (int): seed value
            b (int):number of nodes in the graph
            c (int):probability for edge creation
            d (int):vechile count
            e (int):vechile capacity
            f (int):total number of clock ticks

        Returns:
            networkx.classes.graph.Graph
        """
        try:
            seed=a
            self.n=b
            self.p=c
            self.vechile_count=d
            self.vechile_capacity=e
            self.total_clock_ticks=f
            G= nx.gnp_random_graph (self.n,p=self.p, seed=seed)
            print ( G.nodes() )
            return G
        except Exception as e:
            raise e

    def generate_connected_graph(self, a, b, d, e, f):
        """
        This function creates a fully connected graph
        and prints the value of probability for edge creation  for the following nodes
          Args:
            a (int): seed value
            b (int):number of nodes in the graph
            c (int):probability for edge creation
            d (int):vechile count
            e (int):vechile capacity
            f (int):total number of clock ticks

        Returns:
            networkx.classes.graph.Graph
        """
        try:
            k = 4
            c = k / (b - 1)
            f1 = 0
            while f1 == 0:
                G = self.GenerateGraph(a, b, c, d, e, f)
                if nx.is_connected(G):
                    print("p:", c)
                    return G
                c += 0.01
        except Exception as e:
            raise e

    def add_weights_to_graph(self, weights, G):
        """
        This function creates edges between the nodes and assign weights to those edges
        Args:
            weights (list):In this list we have values stored in namedtuple which takes three values staring node,ending node,weight of the edge
            G (Graph object):Graph object

        Returns:
            networkx.classes.graph.Graph
            _
        """
        try:
            if weights is None:
                for u, v in G.edges:
                    G.add_edge(u, v, weight=round(random.random(), 1))
            else:
                for u, v, w in weights:
                    G.add_edge(u, v, weight=w)
            return G
        except Exception as e:
            raise e

    def update(self):
        """
        updates the position of vechiles in each clock tick
        """
        try:
            for i in range(self.d):
                if len(self.vechile_list[i]) >= 1:
                    curr_customer = self.vechile_list[i][0]
                    key = list(curr_customer.keys())[0]
                    pick_up = curr_customer[key][0]
                    index = 0
                    if pick_up == -1:
                        index = 1
                    loc = curr_customer[key][index]
                    curr_loc = self.curr_vechile_location[i]
                    new_loc = self.get_next_node(self.G, curr_loc, loc)
                    self.vechile_travelled[i].append(new_loc)
                    travel_dist = self.get_shortest_distance(self.G, curr_loc, loc)
                    self.curr_vechile_location[i] = new_loc
                    self.vechile_travel_distance[i] = self.vechile_travel_distance[i] + travel_dist
        except Exception as e:
            raise e


    def take_ride_requests(self, G):
        """
        This function takes G as input and checks if a new request is made if made add it to its near vechile list and rearrange priorities of the vechile
        """
        try:
            reservations_per_hour = random.randint(450, 600)
            reservations_per_tick = reservations_per_hour / self.total_clock_ticks
            for tick in range(1, self.total_clock_ticks + 1):
                if random.random() < reservations_per_tick:
                    cust_id = "customer" + str(self.count)
                    self.count = self.count + 1
                    pick_up = random.randint(0, self.b - 1)
                    drop = random.randint(0, self.b - 1)
                    self.cust_list.append([pick_up, drop])
                    distance, vechile_no = self.Assign_values(pick_up, self.d)
                    if distance == -1:
                        return -1
                    self.no_of_trips = self.no_of_trips + 1
                    re = {cust_id: [pick_up, drop]}
                    re1 = [(cust_id, 'p', pick_up)]
                    re2 = [(cust_id, 'd', drop)]
                    self.vechile_track[vechile_no] = self.vechile_track[vechile_no] + re1 + re2
                    self.no_of_passengers[vechile_no] = self.no_of_passengers[vechile_no] + 1
                    self.vechile_list[vechile_no].append(re)
                    if self.no_of_passengers[vechile_no] > 1:
                        self.vechile_list[vechile_no] = self.rearrange(vechile_no)
            self.update()
        except Exception as e:
            raise e


    def pick_customers(self):
        """
        It takes number of vechiles as argument and return a list where vechile travel distance is equal to 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        for i in range(self.d):
            curr_loc = self.curr_vechile_location[i]
            if len(self.vechile_list[i]) > 0:
                curr_customer = self.vechile_list[i][0]
                key = list(curr_customer.keys())[0]
                pick_up = curr_customer[key][0]
                if pick_up >= 0:
                    if pick_up == curr_loc:
                        self.cus_dir[key] = [key, pick_up]
                        curr_customer[key][0] = -1
                        print("Vehicle", i, "picked up customer", key)
                        curr_customer[key].append(self.vechile_travel_distance[i])
                        curr_customer[key].append(self.clock_ticks)
                        self.vechile_list[i][0] = curr_customer
                        self.vechile_track[i].pop(0)

    def drop_customers(self):
        """
        It takes number of vechiles as argument and return a list where vechile travel distance is equal to 0
        Args:
            d (int):vechiles number

        Returns:
            list
        """
        for i in range(self.d):
            curr_loc = self.curr_vechile_location[i]
            if len(self.vechile_list[i]) > 0:
                curr_customer = self.vechile_list[i][0]
                key = list(curr_customer.keys())[0]
                drop = curr_customer[key][1]
                pick_up = curr_customer[key][0]
                if pick_up == -1:
                    if drop == curr_loc:
                        self.cus_dir[key].append(curr_customer[key][1])
                        travel = self.vechile_travel_distance[i] - curr_customer[key][2]
                        time = self.clock_ticks - curr_customer[key][3]
                        self.cus_dir[key].append(travel)
                        self.cus_dir[key].append(time)
                        print("Vehicle", i, "dropped off customer", key)
                        self.vechile_list[i].pop(0)
                        self.vechile_track[i].pop(0)
                        self.no_of_passengers[i] = self.no_of_passengers[i] - 1

    def average_distance(self):
        """
        This function return average_distance travelled by a car
        """
        total_distance = sum(self.vechile_travel_distance)
        return total_distance / self.d

    def average_trips(self):
        """
        This function returns average no of trips travelled
        Returns:
            int
        """
        return self.no_of_trips / self.f
    def get_shortest_distance(self,G,a,b):
        """
        This function takes starting node and ending node and return shortest distance between them
        Args:
            G (Graph object):Graph object
            a (Node):starting node
            b (Node): ending node

        Returns:
            float number
        """
        try:
            return nx.astar_path_length(self.G,a,b)
        except Exception as e:
            raise e
    def get_next_node(self,G,a,b):
        """
        return the nextnode the van is going to take
        Args:
            G (Graph object)
            a (Node)
            b (Node)

        Returns:
            node
        """
        try:
            shortest_path=nx.astar_path(G,a,b)
            if(len(shortest_path)==1):
                return shortest_path[0]
            else:
                return shortest_path[1]
        except Exception as e:
            raise  e
    def check(self,b):
        """
        It checks the capacity of the vechile that the current vechile can take a new customer or not
        Args:
            b (_type_): _description_

        Returns:
            _type_: _description_
        """
        try:
            capacity=self.e
            if self.no_of_passengers[b]<capacity:
                return 1
            else:
                return 0
        except Exception as e:
            raise  e
    def Assign_values(self,a,b):
        """
          It takes pickup point and vechile list as argument and return the minimum distance and vechile to be assigned as output
        Args:
            a (Node): PickupNode
            b (list): vechilesnumber
        Returns:
            int,int
        """
        try:
            curr_distance=float('inf')
            vechile_number=None
            count=0
            passengers=6
            for i in range(b):
                if self.check(i)==1:
                    l=self.curr_vechile_location[i]
                    distance=self.get_shortest_distance(self.G,a,l)
                    if curr_distance>distance:
                        curr_distance=distance
                        vechile_number=i
                        passengers=self.no_of_passengers[i]
                    if curr_distance==distance:
                        if self.no_of_passengers[i]<passengers:
                            passengers=self.no_of_passengers[i]
                            curr_distance=distance
                            vechile_number=i
                    #print(vechile_number,"joijoijo")

            if curr_distance==float('inf'):
                print("No vans are available, try again in 15 minutes")
                return -1,None
            else:
                return curr_distance,vechile_number
        except Exception as e:
            raise  e
    def rearrange(self,a):
        """
        It rearranges the vechile list according to vechile current location
        Args:
            a (_type_):vechile_no

        Returns:
            list
        """
        try:
            dict1={}
            count=0
            for i in self.vechile_list[a]:
                dict1[count]=i
                count=count+1
            q=list(dict1[0].keys())[0]
            q1=dict1[0]
            w=q1[q][0]
            list4=[]
            if w==-1:
                list4.append(dict1[0])
                dict1.pop(0)
            v=self.curr_vechile_location[a]
            while len(dict1)>0:
                curr_key=None
                distance=float('inf')
                curr_value=None
                for i in dict1:
                    key=list(dict1[i].keys())[0]
                    dict2=dict1[i]
                    value=dict2[key][0]
                    temp=self.get_shortest_distance(self.G,v,value)
                    if temp<distance:
                        curr_key=i
                        curr_value=value
                        distance=temp
                list4.append(dict1[curr_key])
                v=curr_value
                dict1.pop(curr_key)
            #print(list4)
            return list4

        except Exception as e:
            raise  e

if __name__ == "__main__":
    uber_simulator = Uber()
# Out:
# Streaming output truncated to the last 5000 lines.
# Vehicle 22 dropped off customer customer3221
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer1563
# Vehicle 10 picked up customer customer3233
# Vehicle 15 picked up customer customer3237
# Vehicle 25 picked up customer customer3230
# Vehicle 11 dropped off customer customer3213
# Vehicle 14 dropped off customer customer3210
# Vehicle 23 dropped off customer customer3184
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3171
# Vehicle 8 picked up customer customer3251
# Vehicle 18 dropped off customer customer3134
# Vehicle 19 dropped off customer customer3162
# Vehicle 28 dropped off customer customer3190
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3247
# Vehicle 14 picked up customer customer3235
# Vehicle 18 picked up customer customer3217
# Vehicle 24 picked up customer customer3194
# Vehicle 26 picked up customer customer3156
# Vehicle 10 dropped off customer customer3233
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3249
# Vehicle 7 picked up customer customer3248
# Vehicle 9 picked up customer customer3200
# Vehicle 16 picked up customer customer3234
# Vehicle 22 picked up customer customer3252
# Vehicle 12 dropped off customer customer3219
# Vehicle 15 dropped off customer customer3237
# Vehicle 20 dropped off customer customer3165
# Vehicle 26 dropped off customer customer3156
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3244
# Vehicle 11 picked up customer customer3255
# Vehicle 17 picked up customer customer3215
# Vehicle 8 dropped off customer customer3251
# Vehicle 16 dropped off customer customer3234
# Vehicle 27 dropped off customer customer3207
# No vans are available, try again in 15 minutes
# Vehicle 19 picked up customer customer3260
# Vehicle 28 picked up customer customer3261
# Vehicle 0 dropped off customer customer1563
# Vehicle 2 dropped off customer customer3247
# Vehicle 9 dropped off customer customer3200
# Vehicle 21 dropped off customer customer3202
# Vehicle 24 dropped off customer customer3194
# Vehicle 25 dropped off customer customer3230
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3250
# Vehicle 10 picked up customer customer3263
# Vehicle 12 picked up customer customer2906
# Vehicle 13 picked up customer customer3243
# Vehicle 15 picked up customer customer1737
# Vehicle 3 dropped off customer customer3227
# Vehicle 11 dropped off customer customer3255
# Vehicle 19 dropped off customer customer3260
# Vehicle 22 dropped off customer customer3252
# Vehicle 29 dropped off customer customer3166
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3272
# Vehicle 20 picked up customer customer3196
# Vehicle 26 picked up customer customer3265
# Vehicle 1 dropped off customer customer3171
# Vehicle 14 dropped off customer customer3235
# Vehicle 17 dropped off customer customer3215
# Vehicle 28 dropped off customer customer3261
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3281
# Vehicle 11 picked up customer customer3283
# Vehicle 14 picked up customer customer2018
# Vehicle 23 picked up customer customer3257
# Vehicle 29 picked up customer customer3138
# Vehicle 18 dropped off customer customer3217
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3274
# Vehicle 17 picked up customer customer3180
# Vehicle 28 picked up customer customer3214
# Vehicle 5 dropped off customer customer3249
# Vehicle 7 dropped off customer customer3248
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3276
# Vehicle 1 picked up customer customer3222
# Vehicle 16 picked up customer customer3271
# Vehicle 27 picked up customer customer3175
# Vehicle 6 dropped off customer customer3244
# No vans are available, try again in 15 minutes
# Vehicle 19 picked up customer customer3285
# Vehicle 21 picked up customer customer3277
# Vehicle 4 dropped off customer customer3250
# Vehicle 11 dropped off customer customer3283
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer2674
# Vehicle 7 picked up customer customer3294
# Vehicle 9 picked up customer customer3275
# Vehicle 24 picked up customer customer3279
# Vehicle 12 dropped off customer customer2906
# Vehicle 13 dropped off customer customer3243
# Vehicle 15 dropped off customer customer1737
# Vehicle 23 dropped off customer customer3257
# Vehicle 26 dropped off customer customer3265
# Vehicle 28 dropped off customer customer3214
# Vehicle 29 dropped off customer customer3138
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3300
# Vehicle 6 picked up customer customer2813
# Vehicle 11 picked up customer customer2742
# Vehicle 22 picked up customer customer3282
# Vehicle 29 picked up customer customer3306
# Vehicle 1 dropped off customer customer3222
# Vehicle 2 dropped off customer customer3274
# Vehicle 10 dropped off customer customer3263
# Vehicle 14 dropped off customer customer2018
# Vehicle 17 dropped off customer customer3180
# No vans are available, try again in 15 minutes
# Vehicle 18 picked up customer customer3292
# Vehicle 25 picked up customer customer3278
# Vehicle 8 dropped off customer customer3272
# Vehicle 9 dropped off customer customer3275
# Vehicle 20 dropped off customer customer3196
# No vans are available, try again in 15 minutes
# Vehicle 28 picked up customer customer3305
# Vehicle 4 dropped off customer customer3300
# Vehicle 27 dropped off customer customer3175
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3211
# Vehicle 8 picked up customer customer2991
# Vehicle 10 picked up customer customer3128
# Vehicle 15 picked up customer customer3303
# Vehicle 5 dropped off customer customer2674
# Vehicle 18 dropped off customer customer3292
# No vans are available, try again in 15 minutes
# Vehicle 13 picked up customer customer2926
# Vehicle 17 picked up customer customer3311
# Vehicle 23 picked up customer customer3212
# Vehicle 22 dropped off customer customer3282
# No vans are available, try again in 15 minutes
# Vehicle 14 picked up customer customer2852
# Vehicle 18 picked up customer customer3323
# Vehicle 3 dropped off customer customer3281
# Vehicle 6 dropped off customer customer2813
# Vehicle 11 dropped off customer customer2742
# Vehicle 28 dropped off customer customer3305
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3312
# Vehicle 0 dropped off customer customer3276
# Vehicle 2 dropped off customer customer3211
# Vehicle 7 dropped off customer customer3294
# Vehicle 8 dropped off customer customer2991
# Vehicle 10 dropped off customer customer3128
# Vehicle 25 dropped off customer customer3278
# Vehicle 29 dropped off customer customer3306
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer1634
# Vehicle 21 dropped off customer customer3277
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3321
# Vehicle 5 picked up customer customer3324
# Vehicle 6 picked up customer customer3330
# Vehicle 9 picked up customer customer3318
# Vehicle 20 picked up customer customer2523
# Vehicle 25 picked up customer customer3333
# Vehicle 27 picked up customer customer349
# Vehicle 16 dropped off customer customer3271
# Vehicle 23 dropped off customer customer3212
# Vehicle 24 dropped off customer customer3279
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3153
# Vehicle 8 picked up customer customer3337
# Vehicle 11 picked up customer customer3328
# Vehicle 12 picked up customer customer3267
# Vehicle 21 picked up customer customer3229
# Vehicle 19 dropped off customer customer3285
# No vans are available, try again in 15 minutes
# Vehicle 3 dropped off customer customer1634
# Vehicle 13 dropped off customer customer2926
# Vehicle 18 dropped off customer customer3323
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3336
# Vehicle 22 picked up customer customer3177
# Vehicle 24 picked up customer customer3344
# Vehicle 26 picked up customer customer3225
# Vehicle 15 dropped off customer customer3303
# Vehicle 25 dropped off customer customer3333
# Vehicle 27 dropped off customer customer349
# No vans are available, try again in 15 minutes
# Vehicle 10 picked up customer customer3310
# Vehicle 23 picked up customer customer3302
# Vehicle 25 picked up customer customer1456
# Vehicle 28 picked up customer customer3331
# Vehicle 1 dropped off customer customer3312
# Vehicle 4 dropped off customer customer3321
# Vehicle 8 dropped off customer customer3337
# Vehicle 12 dropped off customer customer3267
# Vehicle 14 dropped off customer customer2852
# Vehicle 17 dropped off customer customer3311
# Vehicle 21 dropped off customer customer3229
# Vehicle 26 dropped off customer customer3225
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3329
# Vehicle 7 picked up customer customer3167
# Vehicle 2 dropped off customer customer3153
# No vans are available, try again in 15 minutes
# Vehicle 12 picked up customer customer2783
# Vehicle 14 picked up customer customer3359
# Vehicle 17 picked up customer customer3358
# Vehicle 21 picked up customer customer3341
# Vehicle 5 dropped off customer customer3324
# Vehicle 6 dropped off customer customer3330
# Vehicle 10 dropped off customer customer3310
# Vehicle 20 dropped off customer customer2523
# Vehicle 28 dropped off customer customer3331
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3317
# Vehicle 16 picked up customer customer3343
# Vehicle 18 picked up customer customer3259
# Vehicle 19 picked up customer customer3347
# Vehicle 26 picked up customer customer3364
# Vehicle 29 picked up customer customer3335
# Vehicle 9 dropped off customer customer3318
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3363
# Vehicle 6 picked up customer customer3297
# Vehicle 27 picked up customer customer3353
# Vehicle 3 dropped off customer customer3329
# Vehicle 25 dropped off customer customer1456
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3360
# Vehicle 13 picked up customer customer3349
# Vehicle 28 picked up customer customer3287
# Vehicle 17 dropped off customer customer3358
# Vehicle 21 dropped off customer customer3341
# Vehicle 24 dropped off customer customer3344
# Vehicle 26 dropped off customer customer3364
# No vans are available, try again in 15 minutes
# Vehicle 15 picked up customer customer3268
# Vehicle 20 picked up customer customer3316
# No vans are available, try again in 15 minutes
# Vehicle 10 picked up customer customer3339
# Vehicle 25 picked up customer customer3355
# Vehicle 0 dropped off customer customer3336
# Vehicle 7 dropped off customer customer3167
# Vehicle 8 dropped off customer customer3317
# Vehicle 11 dropped off customer customer3328
# Vehicle 16 dropped off customer customer3343
# Vehicle 19 dropped off customer customer3347
# Vehicle 23 dropped off customer customer3302
# Vehicle 28 dropped off customer customer3287
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3314
# Vehicle 1 dropped off customer customer3360
# Vehicle 20 dropped off customer customer3316
# Vehicle 29 dropped off customer customer3335
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3376
# Vehicle 8 picked up customer customer3385
# Vehicle 19 picked up customer customer3387
# Vehicle 23 picked up customer customer3345
# Vehicle 24 picked up customer customer3379
# Vehicle 14 dropped off customer customer3359
# Vehicle 27 dropped off customer customer3353
# No vans are available, try again in 15 minutes
# Vehicle 9 picked up customer customer3187
# Vehicle 17 picked up customer customer3253
# Vehicle 20 picked up customer customer3266
# Vehicle 26 picked up customer customer3382
# Vehicle 22 dropped off customer customer3177
# Vehicle 24 dropped off customer customer3379
# No vans are available, try again in 15 minutes
# Vehicle 11 picked up customer customer3299
# Vehicle 16 picked up customer customer3389
# Vehicle 21 picked up customer customer3357
# Vehicle 4 dropped off customer customer3363
# Vehicle 12 dropped off customer customer2783
# Vehicle 18 dropped off customer customer3259
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3396
# Vehicle 5 picked up customer customer3368
# Vehicle 14 picked up customer customer3256
# Vehicle 28 picked up customer customer2876
# Vehicle 6 dropped off customer customer3297
# Vehicle 15 dropped off customer customer3268
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3246
# Vehicle 7 picked up customer customer2960
# Vehicle 29 picked up customer customer3395
# Vehicle 2 dropped off customer customer3314
# Vehicle 8 dropped off customer customer3385
# Vehicle 10 dropped off customer customer3339
# Vehicle 13 dropped off customer customer3349
# Vehicle 14 dropped off customer customer3256
# Vehicle 26 dropped off customer customer3382
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3366
# Vehicle 4 picked up customer customer3404
# Vehicle 10 picked up customer customer2843
# Vehicle 15 picked up customer customer3354
# Vehicle 5 dropped off customer customer3368
# Vehicle 17 dropped off customer customer3253
# Vehicle 23 dropped off customer customer3345
# Vehicle 29 dropped off customer customer3395
# No vans are available, try again in 15 minutes
# Vehicle 14 picked up customer customer3290
# Vehicle 18 picked up customer customer3351
# Vehicle 24 picked up customer customer3401
# Vehicle 27 picked up customer customer3399
# Vehicle 29 picked up customer customer3197
# Vehicle 11 dropped off customer customer3299
# Vehicle 25 dropped off customer customer3355
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3408
# Vehicle 3 dropped off customer customer3376
# Vehicle 9 dropped off customer customer3187
# Vehicle 28 dropped off customer customer2876
# Vehicle 29 dropped off customer customer3197
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3361
# Vehicle 26 picked up customer customer3414
# Vehicle 1 dropped off customer customer3396
# Vehicle 2 dropped off customer customer3366
# Vehicle 7 dropped off customer customer2960
# Vehicle 15 dropped off customer customer3354
# Vehicle 18 dropped off customer customer3351
# Vehicle 20 dropped off customer customer3266
# Vehicle 21 dropped off customer customer3357
# Vehicle 24 dropped off customer customer3401
# No vans are available, try again in 15 minutes
# Vehicle 12 picked up customer customer3405
# Vehicle 13 picked up customer customer3413
# Vehicle 21 picked up customer customer3380
# Vehicle 22 picked up customer customer3402
# Vehicle 0 dropped off customer customer3246
# Vehicle 19 dropped off customer customer3387
# Vehicle 27 dropped off customer customer3399
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3431
# Vehicle 17 picked up customer customer1544
# Vehicle 29 picked up customer customer3418
# Vehicle 10 dropped off customer customer2843
# No vans are available, try again in 15 minutes
# Vehicle 7 picked up customer customer3432
# Vehicle 23 picked up customer customer3386
# Vehicle 4 dropped off customer customer3404
# Vehicle 8 dropped off customer customer3361
# Vehicle 13 dropped off customer customer3413
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3421
# Vehicle 11 picked up customer customer3424
# Vehicle 20 picked up customer customer3372
# Vehicle 25 picked up customer customer3377
# Vehicle 28 picked up customer customer3390
# Vehicle 16 dropped off customer customer3389
# Vehicle 29 dropped off customer customer3418
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3289
# Vehicle 13 picked up customer customer2724
# Vehicle 24 picked up customer customer3435
# Vehicle 14 dropped off customer customer3290
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3426
# Vehicle 18 picked up customer customer3406
# Vehicle 29 picked up customer customer3429
# Vehicle 2 dropped off customer customer3431
# Vehicle 6 dropped off customer customer3408
# Vehicle 21 dropped off customer customer3380
# Vehicle 28 dropped off customer customer3390
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3446
# Vehicle 8 picked up customer customer3412
# Vehicle 9 picked up customer customer3427
# Vehicle 15 picked up customer customer3436
# Vehicle 7 dropped off customer customer3432
# Vehicle 12 dropped off customer customer3405
# Vehicle 13 dropped off customer customer2724
# Vehicle 22 dropped off customer customer3402
# Vehicle 23 dropped off customer customer3386
# Vehicle 25 dropped off customer customer3377
# Vehicle 26 dropped off customer customer3414
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3415
# Vehicle 17 dropped off customer customer1544
# Vehicle 18 dropped off customer customer3406
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3391
# Vehicle 7 picked up customer customer3460
# Vehicle 17 picked up customer customer3381
# Vehicle 21 picked up customer customer3434
# Vehicle 25 picked up customer customer3423
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3369
# Vehicle 12 picked up customer customer3463
# Vehicle 13 picked up customer customer3466
# Vehicle 19 picked up customer customer3441
# Vehicle 22 picked up customer customer3462
# Vehicle 28 picked up customer customer3428
# Vehicle 8 dropped off customer customer3412
# Vehicle 20 dropped off customer customer3372
# No vans are available, try again in 15 minutes
# Vehicle 14 picked up customer customer3398
# Vehicle 26 picked up customer customer3461
# Vehicle 27 picked up customer customer3320
# Vehicle 5 dropped off customer customer3421
# Vehicle 7 dropped off customer customer3460
# Vehicle 24 dropped off customer customer3435
# No vans are available, try again in 15 minutes
# Vehicle 10 picked up customer customer3416
# Vehicle 23 picked up customer customer3464
# Vehicle 11 dropped off customer customer3424
# Vehicle 17 dropped off customer customer3381
# No vans are available, try again in 15 minutes
# Vehicle 1 dropped off customer customer3289
# Vehicle 3 dropped off customer customer3426
# Vehicle 4 dropped off customer customer3446
# Vehicle 28 dropped off customer customer3428
# No vans are available, try again in 15 minutes
# Vehicle 16 picked up customer customer3450
# Vehicle 18 picked up customer customer3437
# Vehicle 6 dropped off customer customer3369
# Vehicle 9 dropped off customer customer3427
# Vehicle 15 dropped off customer customer3436
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3483
# Vehicle 7 picked up customer customer3476
# Vehicle 20 picked up customer customer3438
# Vehicle 24 picked up customer customer3240
# Vehicle 10 dropped off customer customer3416
# Vehicle 21 dropped off customer customer3434
# Vehicle 25 dropped off customer customer3423
# Vehicle 29 dropped off customer customer3429
# No vans are available, try again in 15 minutes
# Vehicle 0 dropped off customer customer3391
# Vehicle 2 dropped off customer customer3415
# Vehicle 12 dropped off customer customer3463
# Vehicle 13 dropped off customer customer3466
# Vehicle 19 dropped off customer customer3441
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer1899
# Vehicle 4 picked up customer customer3482
# Vehicle 5 picked up customer customer3475
# Vehicle 8 picked up customer customer3472
# Vehicle 19 picked up customer customer3499
# Vehicle 25 picked up customer customer2944
# Vehicle 28 picked up customer customer3457
# Vehicle 16 dropped off customer customer3450
# Vehicle 18 dropped off customer customer3437
# Vehicle 22 dropped off customer customer3462
# Vehicle 23 dropped off customer customer3464
# No vans are available, try again in 15 minutes
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3496
# Vehicle 6 picked up customer customer3455
# Vehicle 10 picked up customer customer3492
# Vehicle 17 picked up customer customer3479
# Vehicle 18 picked up customer customer3468
# Vehicle 21 picked up customer customer3458
# Vehicle 14 dropped off customer customer3398
# No vans are available, try again in 15 minutes
# Vehicle 9 picked up customer customer3488
# Vehicle 11 picked up customer customer3480
# Vehicle 22 picked up customer customer3326
# Vehicle 5 dropped off customer customer3475
# Vehicle 8 dropped off customer customer3472
# Vehicle 20 dropped off customer customer3438
# Vehicle 24 dropped off customer customer3240
# Vehicle 27 dropped off customer customer3320
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3231
# Vehicle 15 picked up customer customer3126
# Vehicle 28 dropped off customer customer3457
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3456
# Vehicle 23 picked up customer customer3420
# Vehicle 4 dropped off customer customer3482
# Vehicle 25 dropped off customer customer2944
# No vans are available, try again in 15 minutes
# Vehicle 13 picked up customer customer3448
# Vehicle 24 picked up customer customer2779
# Vehicle 1 dropped off customer customer1899
# Vehicle 6 dropped off customer customer3455
# Vehicle 10 dropped off customer customer3492
# Vehicle 17 dropped off customer customer3479
# Vehicle 19 dropped off customer customer3499
# Vehicle 21 dropped off customer customer3458
# Vehicle 26 dropped off customer customer3461
# No vans are available, try again in 15 minutes
# Vehicle 12 picked up customer customer3498
# Vehicle 14 picked up customer customer3313
# Vehicle 16 picked up customer customer3505
# Vehicle 27 picked up customer customer3510
# Vehicle 28 picked up customer customer3485
# Vehicle 3 dropped off customer customer3483
# Vehicle 7 dropped off customer customer3476
# Vehicle 22 dropped off customer customer3326
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3487
# Vehicle 8 picked up customer customer3512
# Vehicle 26 picked up customer customer3524
# Vehicle 29 picked up customer customer3451
# Vehicle 23 dropped off customer customer3420
# No vans are available, try again in 15 minutes
# Vehicle 20 picked up customer customer3511
# Vehicle 25 picked up customer customer3519
# Vehicle 11 dropped off customer customer3480
# Vehicle 18 dropped off customer customer3468
# Vehicle 27 dropped off customer customer3510
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3521
# Vehicle 10 picked up customer customer3522
# Vehicle 11 picked up customer customer3388
# Vehicle 18 picked up customer customer3502
# Vehicle 21 picked up customer customer3493
# Vehicle 13 dropped off customer customer3448
# Vehicle 26 dropped off customer customer3524
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3530
# Vehicle 19 picked up customer customer3241
# Vehicle 0 dropped off customer customer3496
# Vehicle 24 dropped off customer customer2779
# Vehicle 28 dropped off customer customer3485
# No vans are available, try again in 15 minutes
# Vehicle 9 dropped off customer customer3488
# Vehicle 18 dropped off customer customer3502
# Vehicle 20 dropped off customer customer3511
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3442
# Vehicle 4 picked up customer customer3518
# Vehicle 7 picked up customer customer1757
# Vehicle 17 picked up customer customer3526
# Vehicle 23 picked up customer customer3503
# Vehicle 12 dropped off customer customer3498
# Vehicle 14 dropped off customer customer3313
# Vehicle 15 dropped off customer customer3126
# Vehicle 19 dropped off customer customer3241
# Vehicle 21 dropped off customer customer3493
# Vehicle 29 dropped off customer customer3451
# No vans are available, try again in 15 minutes
# Vehicle 18 picked up customer customer2866
# Vehicle 19 picked up customer customer3527
# Vehicle 22 picked up customer customer3504
# Vehicle 27 picked up customer customer3535
# Vehicle 2 dropped off customer customer3456
# Vehicle 6 dropped off customer customer3487
# No vans are available, try again in 15 minutes
# Vehicle 12 picked up customer customer3307
# Vehicle 15 picked up customer customer3489
# Vehicle 21 picked up customer customer2684
# Vehicle 24 picked up customer customer3543
# Vehicle 28 picked up customer customer3516
# Vehicle 5 dropped off customer customer3231
# Vehicle 16 dropped off customer customer3505
# No vans are available, try again in 15 minutes
# Vehicle 16 picked up customer customer2278
# Vehicle 20 picked up customer customer3546
# Vehicle 26 picked up customer customer3539
# Vehicle 1 dropped off customer customer3521
# Vehicle 3 dropped off customer customer3530
# Vehicle 8 dropped off customer customer3512
# Vehicle 10 dropped off customer customer3522
# Vehicle 25 dropped off customer customer3519
# Vehicle 28 dropped off customer customer3516
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3557
# Vehicle 28 picked up customer customer3565
# Vehicle 29 picked up customer customer3494
# Vehicle 11 dropped off customer customer3388
# Vehicle 27 dropped off customer customer3535
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3523
# Vehicle 7 dropped off customer customer1757
# Vehicle 17 dropped off customer customer3526
# Vehicle 18 dropped off customer customer2866
# Vehicle 20 dropped off customer customer3546
# Vehicle 23 dropped off customer customer3503
# No vans are available, try again in 15 minutes
# Vehicle 13 picked up customer customer3540
# Vehicle 2 dropped off customer customer3557
# Vehicle 12 dropped off customer customer3307
# Vehicle 19 dropped off customer customer3527
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3560
# Vehicle 9 picked up customer customer3547
# Vehicle 11 picked up customer customer3537
# Vehicle 14 picked up customer customer3508
# Vehicle 18 picked up customer customer3536
# Vehicle 0 dropped off customer customer3442
# Vehicle 15 dropped off customer customer3489
# Vehicle 21 dropped off customer customer2684
# Vehicle 22 dropped off customer customer3504
# No vans are available, try again in 15 minutes
# Vehicle 10 picked up customer customer3568
# Vehicle 12 picked up customer customer3554
# Vehicle 17 picked up customer customer3576
# Vehicle 19 picked up customer customer3581
# Vehicle 20 picked up customer customer2998
# Vehicle 28 dropped off customer customer3565
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3563
# Vehicle 3 picked up customer customer3564
# Vehicle 7 picked up customer customer999
# Vehicle 8 picked up customer customer3566
# Vehicle 15 picked up customer customer3550
# Vehicle 4 dropped off customer customer3518
# Vehicle 14 dropped off customer customer3508
# Vehicle 16 dropped off customer customer2278
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3542
# Vehicle 23 picked up customer customer3573
# Vehicle 9 dropped off customer customer3547
# Vehicle 18 dropped off customer customer3536
# Vehicle 24 dropped off customer customer3543
# Vehicle 26 dropped off customer customer3539
# No vans are available, try again in 15 minutes
# Vehicle 21 picked up customer customer3555
# Vehicle 22 picked up customer customer3583
# Vehicle 8 dropped off customer customer3566
# Vehicle 29 dropped off customer customer3494
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3579
# Vehicle 16 picked up customer customer3561
# Vehicle 25 picked up customer customer3567
# Vehicle 5 dropped off customer customer3560
# No vans are available, try again in 15 minutes
# Vehicle 9 picked up customer customer3596
# Vehicle 14 picked up customer customer3411
# Vehicle 24 picked up customer customer3595
# Vehicle 27 picked up customer customer3570
# Vehicle 1 dropped off customer customer3563
# Vehicle 6 dropped off customer customer3523
# Vehicle 11 dropped off customer customer3537
# Vehicle 12 dropped off customer customer3554
# Vehicle 13 dropped off customer customer3540
# Vehicle 19 dropped off customer customer3581
# Vehicle 20 dropped off customer customer2998
# Vehicle 23 dropped off customer customer3573
# No vans are available, try again in 15 minutes
# Vehicle 28 picked up customer customer3544
# Vehicle 29 picked up customer customer3284
# Vehicle 7 dropped off customer customer999
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3201
# Vehicle 0 dropped off customer customer3542
# Vehicle 8 dropped off customer customer3201
# Vehicle 15 dropped off customer customer3550
# Vehicle 17 dropped off customer customer3576
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3591
# Vehicle 6 picked up customer customer3558
# Vehicle 7 picked up customer customer3392
# Vehicle 20 picked up customer customer3394
# Vehicle 10 dropped off customer customer3568
# Vehicle 24 dropped off customer customer3595
# No vans are available, try again in 15 minutes
# Vehicle 18 picked up customer customer3548
# Vehicle 2 dropped off customer customer3579
# Vehicle 3 dropped off customer customer3564
# Vehicle 9 dropped off customer customer3596
# Vehicle 27 dropped off customer customer3570
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3600
# Vehicle 12 picked up customer customer3606
# Vehicle 13 picked up customer customer3605
# Vehicle 17 picked up customer customer3469
# Vehicle 19 picked up customer customer3604
# Vehicle 24 picked up customer customer3513
# Vehicle 26 picked up customer customer3594
# Vehicle 25 dropped off customer customer3567
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3610
# Vehicle 5 picked up customer customer3602
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3500
# Vehicle 15 picked up customer customer3615
# Vehicle 23 picked up customer customer3609
# Vehicle 7 dropped off customer customer3392
# Vehicle 14 dropped off customer customer3411
# Vehicle 16 dropped off customer customer3561
# Vehicle 22 dropped off customer customer3583
# Vehicle 29 dropped off customer customer3284
# No vans are available, try again in 15 minutes
# Vehicle 7 picked up customer customer3613
# Vehicle 9 picked up customer customer3624
# Vehicle 11 picked up customer customer3611
# Vehicle 27 picked up customer customer3440
# Vehicle 6 dropped off customer customer3558
# Vehicle 20 dropped off customer customer3394
# Vehicle 28 dropped off customer customer3544
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3350
# Vehicle 10 picked up customer customer3620
# Vehicle 28 picked up customer customer3588
# Vehicle 4 dropped off customer customer3591
# Vehicle 13 dropped off customer customer3605
# Vehicle 21 dropped off customer customer3555
# Vehicle 24 dropped off customer customer3513
# No vans are available, try again in 15 minutes
# Vehicle 16 picked up customer customer3590
# Vehicle 2 dropped off customer customer3500
# Vehicle 3 dropped off customer customer3350
# Vehicle 8 dropped off customer customer3600
# Vehicle 18 dropped off customer customer3548
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3584
# Vehicle 3 picked up customer customer3623
# Vehicle 19 dropped off customer customer3604
# Vehicle 28 dropped off customer customer3588
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3641
# Vehicle 14 picked up customer customer3453
# Vehicle 21 picked up customer customer3644
# Vehicle 29 picked up customer customer3599
# Vehicle 0 dropped off customer customer3584
# Vehicle 11 dropped off customer customer3611
# Vehicle 12 dropped off customer customer3606
# Vehicle 17 dropped off customer customer3469
# Vehicle 23 dropped off customer customer3609
# Vehicle 26 dropped off customer customer3594
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3626
# Vehicle 6 picked up customer customer3223
# Vehicle 20 picked up customer customer3574
# Vehicle 1 dropped off customer customer3610
# Vehicle 29 dropped off customer customer3599
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3618
# Vehicle 18 picked up customer customer3647
# Vehicle 22 picked up customer customer3531
# Vehicle 26 picked up customer customer3654
# Vehicle 9 dropped off customer customer3624
# Vehicle 10 dropped off customer customer3620
# No vans are available, try again in 15 minutes
# Vehicle 11 picked up customer customer3086
# Vehicle 24 picked up customer customer3642
# Vehicle 25 picked up customer customer3628
# Vehicle 7 dropped off customer customer3613
# Vehicle 20 dropped off customer customer3574
# Vehicle 27 dropped off customer customer3440
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3616
# Vehicle 10 picked up customer customer3444
# Vehicle 12 picked up customer customer3657
# Vehicle 19 picked up customer customer3551
# Vehicle 5 dropped off customer customer3602
# Vehicle 8 dropped off customer customer3618
# Vehicle 21 dropped off customer customer3644
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3661
# Vehicle 23 picked up customer customer3655
# No vans are available, try again in 15 minutes
# Vehicle 13 picked up customer customer3643
# Vehicle 17 picked up customer customer3617
# Vehicle 28 picked up customer customer3637
# Vehicle 3 dropped off customer customer3623
# Vehicle 4 dropped off customer customer3641
# Vehicle 11 dropped off customer customer3086
# Vehicle 14 dropped off customer customer3453
# No vans are available, try again in 15 minutes
# Vehicle 21 picked up customer customer3672
# Vehicle 2 dropped off customer customer3626
# Vehicle 15 dropped off customer customer3615
# Vehicle 22 dropped off customer customer3531
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3646
# Vehicle 4 picked up customer customer3677
# Vehicle 8 picked up customer customer3648
# Vehicle 14 picked up customer customer3592
# Vehicle 16 dropped off customer customer3590
# Vehicle 23 dropped off customer customer3655
# Vehicle 25 dropped off customer customer3628
# No vans are available, try again in 15 minutes
# Vehicle 7 picked up customer customer3668
# Vehicle 29 picked up customer customer3635
# Vehicle 0 dropped off customer customer3616
# Vehicle 6 dropped off customer customer3223
# Vehicle 18 dropped off customer customer3647
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3649
# Vehicle 22 picked up customer customer3681
# Vehicle 21 dropped off customer customer3672
# Vehicle 26 dropped off customer customer3654
# No vans are available, try again in 15 minutes
# Vehicle 20 picked up customer customer3667
# Vehicle 27 picked up customer customer3669
# Vehicle 17 dropped off customer customer3617
# Vehicle 29 dropped off customer customer3635
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3673
# Vehicle 9 picked up customer customer3664
# Vehicle 29 picked up customer customer3662
# Vehicle 2 dropped off customer customer3646
# Vehicle 4 dropped off customer customer3677
# Vehicle 10 dropped off customer customer3444
# Vehicle 12 dropped off customer customer3657
# Vehicle 24 dropped off customer customer3642
# Vehicle 28 dropped off customer customer3637
# No vans are available, try again in 15 minutes
# Vehicle 15 picked up customer customer3586
# Vehicle 16 picked up customer customer3634
# Vehicle 18 picked up customer customer3597
# Vehicle 26 picked up customer customer3308
# Vehicle 1 dropped off customer customer3661
# Vehicle 7 dropped off customer customer3668
# Vehicle 14 dropped off customer customer3592
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3690
# Vehicle 12 picked up customer customer3362
# Vehicle 13 dropped off customer customer3643
# Vehicle 19 dropped off customer customer3551
# No vans are available, try again in 15 minutes
# Vehicle 11 picked up customer customer3676
# Vehicle 24 picked up customer customer3621
# Vehicle 3 dropped off customer customer3649
# Vehicle 8 dropped off customer customer3648
# Vehicle 9 dropped off customer customer3664
# Vehicle 22 dropped off customer customer3681
# Vehicle 27 dropped off customer customer3669
# No vans are available, try again in 15 minutes
# Vehicle 28 picked up customer customer3701
# Vehicle 16 dropped off customer customer3634
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3682
# Vehicle 6 picked up customer customer3691
# Vehicle 9 picked up customer customer3714
# Vehicle 10 picked up customer customer3665
# Vehicle 19 picked up customer customer3652
# Vehicle 25 picked up customer customer3687
# Vehicle 5 dropped off customer customer3673
# Vehicle 20 dropped off customer customer3667
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer566
# Vehicle 14 picked up customer customer3678
# Vehicle 23 picked up customer customer3686
# Vehicle 18 dropped off customer customer3597
# Vehicle 29 dropped off customer customer3662
# No vans are available, try again in 15 minutes
# Vehicle 17 picked up customer customer3696
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3708
# Vehicle 8 picked up customer customer3671
# Vehicle 13 picked up customer customer3710
# Vehicle 16 picked up customer customer3041
# Vehicle 27 picked up customer customer3717
# Vehicle 10 dropped off customer customer3665
# Vehicle 15 dropped off customer customer3586
# Vehicle 25 dropped off customer customer3687
# Vehicle 26 dropped off customer customer3308
# No vans are available, try again in 15 minutes
# Vehicle 15 picked up customer customer3683
# Vehicle 20 picked up customer customer3721
# Vehicle 21 picked up customer customer3693
# Vehicle 22 picked up customer customer2836
# Vehicle 29 picked up customer customer3552
# Vehicle 0 dropped off customer customer3690
# Vehicle 6 dropped off customer customer3691
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3715
# Vehicle 18 picked up customer customer3689
# Vehicle 11 dropped off customer customer3676
# Vehicle 12 dropped off customer customer3362
# Vehicle 19 dropped off customer customer3652
# Vehicle 20 dropped off customer customer3721
# Vehicle 24 dropped off customer customer3621
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3722
# Vehicle 7 picked up customer customer3631
# Vehicle 10 picked up customer customer3700
# Vehicle 4 dropped off customer customer566
# Vehicle 9 dropped off customer customer3714
# Vehicle 27 dropped off customer customer3717
# Vehicle 28 dropped off customer customer3701
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3743
# Vehicle 2 dropped off customer customer3682
# Vehicle 14 dropped off customer customer3678
# Vehicle 16 dropped off customer customer3041
# Vehicle 22 dropped off customer customer2836
# Vehicle 29 dropped off customer customer3552
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3639
# Vehicle 25 picked up customer customer3491
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3658
# Vehicle 19 picked up customer customer3711
# Vehicle 22 picked up customer customer3747
# Vehicle 28 picked up customer customer3744
# Vehicle 29 picked up customer customer3697
# Vehicle 1 dropped off customer customer3708
# Vehicle 8 dropped off customer customer3671
# Vehicle 15 dropped off customer customer3683
# Vehicle 18 dropped off customer customer3689
# Vehicle 23 dropped off customer customer3686
# No vans are available, try again in 15 minutes
# Vehicle 12 picked up customer customer3704
# Vehicle 26 picked up customer customer3728
# Vehicle 3 dropped off customer customer3715
# Vehicle 5 dropped off customer customer3722
# Vehicle 7 dropped off customer customer3631
# Vehicle 13 dropped off customer customer3710
# Vehicle 25 dropped off customer customer3491
# No vans are available, try again in 15 minutes
# Vehicle 9 picked up customer customer3742
# Vehicle 11 picked up customer customer3659
# Vehicle 24 picked up customer customer3737
# Vehicle 27 picked up customer customer3745
# Vehicle 4 dropped off customer customer3743
# Vehicle 6 dropped off customer customer3639
# Vehicle 17 dropped off customer customer3696
# Vehicle 22 dropped off customer customer3747
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3754
# Vehicle 2 picked up customer customer3748
# Vehicle 13 picked up customer customer3304
# Vehicle 23 picked up customer customer3533
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3716
# Vehicle 0 dropped off customer customer3658
# Vehicle 9 dropped off customer customer3742
# Vehicle 12 dropped off customer customer3704
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3760
# Vehicle 4 picked up customer customer3703
# Vehicle 6 picked up customer customer3766
# Vehicle 14 picked up customer customer3749
# Vehicle 17 picked up customer customer3768
# Vehicle 20 picked up customer customer3739
# Vehicle 22 picked up customer customer3767
# Vehicle 25 picked up customer customer3730
# Vehicle 21 dropped off customer customer3693
# Vehicle 24 dropped off customer customer3737
# Vehicle 29 dropped off customer customer3697
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer3761
# Vehicle 7 picked up customer customer3706
# Vehicle 12 picked up customer customer3580
# Vehicle 18 picked up customer customer3725
# Vehicle 8 dropped off customer customer3716
# Vehicle 10 dropped off customer customer3700
# Vehicle 11 dropped off customer customer3659
# Vehicle 19 dropped off customer customer3711
# Vehicle 27 dropped off customer customer3745
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3733
# Vehicle 8 picked up customer customer3756
# Vehicle 9 picked up customer customer3374
# Vehicle 20 dropped off customer customer3739
# Vehicle 28 dropped off customer customer3744
# No vans are available, try again in 15 minutes
# Vehicle 19 picked up customer customer3781
# Vehicle 1 dropped off customer customer3754
# Vehicle 13 dropped off customer customer3304
# Vehicle 14 dropped off customer customer3749
# Vehicle 17 dropped off customer customer3768
# No vans are available, try again in 15 minutes
# Vehicle 11 picked up customer customer3571
# Vehicle 15 picked up customer customer3731
# Vehicle 16 picked up customer customer3750
# Vehicle 24 picked up customer customer3777
# Vehicle 18 dropped off customer customer3725
# Vehicle 25 dropped off customer customer3730
# Vehicle 26 dropped off customer customer3728
# No vans are available, try again in 15 minutes
# Vehicle 0 dropped off customer customer3733
# Vehicle 4 dropped off customer customer3703
# Vehicle 6 dropped off customer customer3766
# Vehicle 22 dropped off customer customer3767
# No vans are available, try again in 15 minutes
# Vehicle 20 picked up customer customer3638
# Vehicle 27 picked up customer customer3625
# Vehicle 23 dropped off customer customer3533
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer3798
# Vehicle 18 picked up customer customer3577
# Vehicle 28 picked up customer customer3786
# Vehicle 29 picked up customer customer3751
# Vehicle 2 dropped off customer customer3748
# Vehicle 3 dropped off customer customer3760
# Vehicle 19 dropped off customer customer3781
# No vans are available, try again in 15 minutes
# Vehicle 21 picked up customer customer3776
# Vehicle 5 dropped off customer customer3761
# Vehicle 7 dropped off customer customer3706
# Vehicle 8 dropped off customer customer3756
# Vehicle 9 dropped off customer customer3374
# Vehicle 11 dropped off customer customer3571
# Vehicle 20 dropped off customer customer3638
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer3792
# Vehicle 17 picked up customer customer3789
# Vehicle 19 picked up customer customer3738
# Vehicle 22 picked up customer customer3799
# Vehicle 23 picked up customer customer3803
# Vehicle 12 dropped off customer customer3580
# Vehicle 27 dropped off customer customer3625
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer3699
# Vehicle 13 picked up customer customer3791
# Vehicle 25 picked up customer customer3795
# Vehicle 26 picked up customer customer3796
# Vehicle 15 dropped off customer customer3731
# Vehicle 16 dropped off customer customer3750
# No vans are available, try again in 15 minutes
# Vehicle 9 picked up customer customer3773
# Vehicle 12 picked up customer customer3772
# Vehicle 29 dropped off customer customer3751
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3801
# Vehicle 7 picked up customer customer3811
# Vehicle 10 picked up customer customer3783
# Vehicle 14 picked up customer customer3707
# Vehicle 20 picked up customer customer3814
# Vehicle 17 dropped off customer customer3789
# Vehicle 21 dropped off customer customer3776
# Vehicle 22 dropped off customer customer3799
# Vehicle 24 dropped off customer customer3777
# Vehicle 28 dropped off customer customer3786
# No vans are available, try again in 15 minutes
# Vehicle 8 picked up customer customer3812
# Vehicle 11 picked up customer customer3782
# Vehicle 15 picked up customer customer3755
# Vehicle 16 picked up customer customer3820
# Vehicle 27 picked up customer customer2814
# Vehicle 1 dropped off customer customer3792
# No vans are available, try again in 15 minutes
# Vehicle 4 dropped off customer customer3798
# Vehicle 13 dropped off customer customer3791
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer3774
# Vehicle 3 picked up customer customer3805
# Vehicle 5 picked up customer customer3813
# Vehicle 9 dropped off customer customer3773
# Vehicle 25 dropped off customer customer3795
# Vehicle 26 dropped off customer customer3796
# No vans are available, try again in 15 minutes
# Vehicle 24 picked up customer customer3827
# Vehicle 28 picked up customer customer3825
# Vehicle 6 dropped off customer customer3801
# Vehicle 7 dropped off customer customer3811
# Vehicle 12 dropped off customer customer3772
# Vehicle 23 dropped off customer customer3803
# No vans are available, try again in 15 minutes
# Vehicle 9 picked up customer customer3835
# Vehicle 17 picked up customer customer3828
# Vehicle 21 picked up customer customer3824
# Vehicle 22 picked up customer customer3826
# Vehicle 29 picked up customer customer3822
# Vehicle 3 dropped off customer customer3805
# Vehicle 5 dropped off customer customer3813
# Vehicle 10 dropped off customer customer3783
# Vehicle 15 dropped off customer customer3755
# Vehicle 16 dropped off customer customer3820
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer1333
# Vehicle 4 picked up customer customer3832
# Vehicle 23 picked up customer customer3839
# Vehicle 2 dropped off customer customer3699
# Vehicle 11 dropped off customer customer3782
# Vehicle 14 dropped off customer customer3707
# Vehicle 18 dropped off customer customer3577
# Vehicle 19 dropped off customer customer3738
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer3131
# Vehicle 12 picked up customer customer2744
# Vehicle 15 picked up customer customer3846
# Vehicle 8 dropped off customer customer3812
# Vehicle 28 dropped off customer customer3825
# No vans are available, try again in 15 minutes
# Vehicle 10 picked up customer customer3844
# Vehicle 16 picked up customer customer3847
# Vehicle 19 picked up customer customer3806
# Vehicle 27 dropped off customer customer2814
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer3050
# Vehicle 25 picked up customer customer3764
# Vehicle 23 dropped off customer customer3839
# Vehicle 24 dropped off customer customer3827
# Vehicle 29 dropped off customer customer3822
# No vans are available, try again in 15 minutes
# Vehicle 0 dropped off customer customer3774
# Vehicle 1 dropped off customer customer1333
# Vehicle 17 dropped off customer customer3828
# Vehicle 20 dropped off customer customer3814
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer2165
# Vehicle 5 picked up customer customer3845
# Vehicle 8 picked up customer customer3857
# Vehicle 13 picked up customer customer3833
# Vehicle 18 picked up customer customer3853
# ...
# Vehicle 29 dropped off customer customer5860
# No vans are available, try again in 15 minutes
# Vehicle 18 picked up customer customer5883
# Vehicle 15 dropped off customer customer5863
# No vans are available, try again in 15 minutes
# Vehicle 3 picked up customer customer5896
# Vehicle 6 picked up customer customer5890
# Vehicle 17 picked up customer customer5889
# Vehicle 19 picked up customer customer5891
# Vehicle 22 picked up customer customer5880
# Vehicle 8 dropped off customer customer5869
# Vehicle 23 dropped off customer customer5851
# Vehicle 27 dropped off customer customer5797
# No vans are available, try again in 15 minutes
# Vehicle 16 picked up customer customer5894
# Vehicle 0 dropped off customer customer5864
# Vehicle 21 dropped off customer customer5865
# No vans are available, try again in 15 minutes
# Vehicle 4 picked up customer customer5795
# Vehicle 12 picked up customer customer5873
# Vehicle 26 picked up customer customer5876
# Vehicle 6 dropped off customer customer5890
# Vehicle 7 dropped off customer customer5830
# Vehicle 11 dropped off customer customer5859
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer5887
# Vehicle 9 dropped off customer customer5861
# Vehicle 22 dropped off customer customer5880
# Vehicle 25 dropped off customer customer5748
# Vehicle 26 dropped off customer customer5876
# No vans are available, try again in 15 minutes
# Vehicle 5 picked up customer customer5882
# Vehicle 20 picked up customer customer5884
# Vehicle 1 dropped off customer customer5874
# Vehicle 13 dropped off customer customer5010
# Vehicle 14 dropped off customer customer5676
# Vehicle 24 dropped off customer customer5866
# No vans are available, try again in 15 minutes
# Vehicle 21 picked up customer customer5905
# Vehicle 23 picked up customer customer5901
# Vehicle 26 picked up customer customer3025
# Vehicle 27 picked up customer customer5870
# Vehicle 28 picked up customer customer5885
# Vehicle 10 dropped off customer customer5671
# Vehicle 12 dropped off customer customer5873
# Vehicle 16 dropped off customer customer5894
# Vehicle 18 dropped off customer customer5883
# Vehicle 19 dropped off customer customer5891
# No vans are available, try again in 15 minutes
# Vehicle 6 picked up customer customer5909
# Vehicle 15 picked up customer customer5898
# Vehicle 29 picked up customer customer5895
# Vehicle 5 dropped off customer customer5882
# Vehicle 27 dropped off customer customer5870
# No vans are available, try again in 15 minutes
# Vehicle 0 picked up customer customer5904
# Vehicle 25 picked up customer customer5911
# No vans are available, try again in 15 minutes
# Vehicle 19 picked up customer customer5853
# Vehicle 15 dropped off customer customer5898
# Vehicle 17 dropped off customer customer5889
# Vehicle 23 dropped off customer customer5901
# Vehicle 26 dropped off customer customer3025
# No vans are available, try again in 15 minutes
# Vehicle 1 picked up customer customer5916
# Vehicle 7 picked up customer customer5907
# Vehicle 8 picked up customer customer5527
# Vehicle 10 picked up customer customer5921
# Vehicle 12 picked up customer customer5922
# Vehicle 23 picked up customer customer5931
# Vehicle 2 dropped off customer customer5887
# Vehicle 3 dropped off customer customer5896
# Vehicle 20 dropped off customer customer5884
# No vans are available, try again in 15 minutes
# Vehicle 14 picked up customer customer5879
# Vehicle 26 picked up customer customer5913
# Vehicle 27 picked up customer customer5902
# Vehicle 4 dropped off customer customer5795
# No vans are available, try again in 15 minutes
# Vehicle 2 picked up customer customer5937
# Vehicle 9 picked up customer customer5912
# Vehicle 13 picked up customer customer5917
# Vehicle 0 dropped off customer customer5904
# Vehicle 19 dropped off customer customer5853
# Vehicle 21 dropped off customer customer5905
# Vehicle 25 dropped off customer customer5911
# Vehicle 15 picked up customer customer5932
# Vehicle 22 picked up customer customer5914
# Vehicle 28 dropped off customer customer5885
# Vehicle 18 picked up customer customer5924
# Vehicle 21 picked up customer customer5805
# Vehicle 6 dropped off customer customer5909
# Vehicle 3 picked up customer customer5807
# Vehicle 5 picked up customer customer5927
# Vehicle 11 picked up customer customer5908
# Vehicle 19 picked up customer customer5925
# Vehicle 1 dropped off customer customer5916
# Vehicle 2 dropped off customer customer5937
# Vehicle 10 dropped off customer customer5921
# Vehicle 23 dropped off customer customer5931
# Vehicle 0 picked up customer customer5491
# Vehicle 16 picked up customer customer5923
# Vehicle 17 picked up customer customer5933
# Vehicle 24 picked up customer customer5918
# Vehicle 8 dropped off customer customer5527
# Vehicle 12 dropped off customer customer5922
# Vehicle 26 dropped off customer customer5913
# Vehicle 29 dropped off customer customer5895
# Vehicle 4 picked up customer customer5892
# Vehicle 10 picked up customer customer5868
# Vehicle 20 picked up customer customer5936
# Vehicle 25 picked up customer customer5200
# Vehicle 7 dropped off customer customer5907
# Vehicle 13 dropped off customer customer5917
# Vehicle 17 dropped off customer customer5933
# Vehicle 18 dropped off customer customer5924
# Vehicle 2 picked up customer customer5623
# Vehicle 23 picked up customer customer5821
# Vehicle 26 picked up customer customer5934
# Vehicle 5 dropped off customer customer5927
# Vehicle 15 dropped off customer customer5932
# Vehicle 19 dropped off customer customer5925
# Vehicle 20 dropped off customer customer5936
# Vehicle 22 dropped off customer customer5914
# Vehicle 13 picked up customer customer1278
# Vehicle 28 picked up customer customer5303
# Vehicle 3 dropped off customer customer5807
# Vehicle 9 dropped off customer customer5912
# Vehicle 16 dropped off customer customer5923
# Vehicle 24 dropped off customer customer5918
# Vehicle 27 dropped off customer customer5902
# Vehicle 1 picked up customer customer5779
# Vehicle 7 picked up customer customer5857
# Vehicle 17 picked up customer customer5771
# Vehicle 14 dropped off customer customer5879
# Vehicle 21 dropped off customer customer5805
# Vehicle 0 dropped off customer customer5491
# Vehicle 7 dropped off customer customer5857
# Vehicle 11 dropped off customer customer5908
# Vehicle 3 picked up customer customer5938
# Vehicle 6 picked up customer customer5811
# Vehicle 15 picked up customer customer5717
# Vehicle 16 picked up customer customer3719
# Vehicle 20 picked up customer customer5156
# Vehicle 17 dropped off customer customer5771
# Vehicle 25 dropped off customer customer5200
# Vehicle 26 dropped off customer customer5934
# Vehicle 28 dropped off customer customer5303
# Vehicle 5 picked up customer customer5077
# Vehicle 11 picked up customer customer5831
# Vehicle 12 picked up customer customer5223
# Vehicle 2 dropped off customer customer5623
# Vehicle 20 dropped off customer customer5156
# Vehicle 23 dropped off customer customer5821
# Vehicle 9 picked up customer customer5280
# Vehicle 18 picked up customer customer2769
# Vehicle 29 picked up customer customer4760
# Vehicle 1 dropped off customer customer5779
# Vehicle 4 dropped off customer customer5892
# Vehicle 13 dropped off customer customer1278
# Vehicle 14 picked up customer customer5919
# Vehicle 12 dropped off customer customer5223
# Vehicle 8 picked up customer customer5900
# Vehicle 24 picked up customer customer5319
# Vehicle 27 picked up customer customer5928
# Vehicle 3 dropped off customer customer5938
# Vehicle 10 dropped off customer customer5868
# Vehicle 11 dropped off customer customer5831
# Vehicle 16 dropped off customer customer3719
# Vehicle 29 dropped off customer customer4760
# Vehicle 19 picked up customer customer2455
# Vehicle 21 picked up customer customer5696
# Vehicle 1 picked up customer customer5350
# Vehicle 7 picked up customer customer5347
# Vehicle 12 picked up customer customer4971
# Vehicle 20 picked up customer customer5780
# Vehicle 26 picked up customer customer5612
# Vehicle 6 dropped off customer customer5811
# Vehicle 14 dropped off customer customer5919
# Vehicle 15 dropped off customer customer5717
# Vehicle 18 dropped off customer customer2769
# Vehicle 4 picked up customer customer5940
# Vehicle 13 picked up customer customer4526
# Vehicle 22 picked up customer customer5763
# Vehicle 25 picked up customer customer177
# Vehicle 24 dropped off customer customer5319
# Vehicle 0 picked up customer customer5550
# Vehicle 2 picked up customer customer5067
# Vehicle 23 picked up customer customer4092
# Vehicle 28 picked up customer customer5738
# Vehicle 11 picked up customer customer5418
# Vehicle 5 dropped off customer customer5077
# Vehicle 9 dropped off customer customer5280
# Vehicle 20 dropped off customer customer5780
# Vehicle 27 dropped off customer customer5928
# Vehicle 16 picked up customer customer5436
# Vehicle 18 picked up customer customer3758
# Vehicle 24 picked up customer customer5757
# Vehicle 29 picked up customer customer5450
# Vehicle 7 dropped off customer customer5347
# Vehicle 8 dropped off customer customer5900
# Vehicle 12 dropped off customer customer4971
# Vehicle 21 dropped off customer customer5696
# Vehicle 22 dropped off customer customer5763
# Vehicle 6 picked up customer customer4859
# Vehicle 17 picked up customer customer1820
# Vehicle 20 picked up customer customer3787
# Vehicle 0 dropped off customer customer5550
# Vehicle 3 picked up customer customer5266
# Vehicle 10 picked up customer customer2276
# Vehicle 13 dropped off customer customer4526
# Vehicle 23 dropped off customer customer4092
# Vehicle 15 picked up customer customer4965
# Vehicle 4 dropped off customer customer5940
# Vehicle 7 picked up customer customer3338
# Vehicle 9 picked up customer customer170
# Vehicle 1 dropped off customer customer5350
# Vehicle 6 dropped off customer customer4859
# Vehicle 11 dropped off customer customer5418
# Vehicle 16 dropped off customer customer5436
# Vehicle 17 dropped off customer customer1820
# Vehicle 19 dropped off customer customer2455
# Vehicle 24 dropped off customer customer5757
# Vehicle 25 dropped off customer customer177
# Vehicle 29 dropped off customer customer5450
# Vehicle 8 picked up customer customer5714
# Vehicle 14 picked up customer customer5212
# Vehicle 27 picked up customer customer5650
# Vehicle 2 dropped off customer customer5067
# Vehicle 7 dropped off customer customer3338
# Vehicle 20 dropped off customer customer3787
# Vehicle 26 dropped off customer customer5612
# Vehicle 0 picked up customer customer2857
# Vehicle 4 picked up customer customer4754
# Vehicle 6 picked up customer customer5849
# Vehicle 12 picked up customer customer4475
# Vehicle 10 dropped off customer customer2276
# Vehicle 13 picked up customer customer5815
# Vehicle 22 picked up customer customer3633
# Vehicle 29 picked up customer customer4402
# Vehicle 15 dropped off customer customer4965
# Vehicle 28 dropped off customer customer5738
# Vehicle 17 picked up customer customer4253
# Vehicle 21 picked up customer customer483
# Vehicle 24 picked up customer customer3052
# Vehicle 3 dropped off customer customer5266
# Vehicle 14 dropped off customer customer5212
# Vehicle 18 dropped off customer customer3758
# Vehicle 19 picked up customer customer5311
# Vehicle 9 dropped off customer customer170
# Vehicle 13 dropped off customer customer5815
# Vehicle 22 dropped off customer customer3633
# Vehicle 27 dropped off customer customer5650
# Vehicle 3 picked up customer customer3151
# Vehicle 15 picked up customer customer319
# Vehicle 23 picked up customer customer2559
# Vehicle 4 dropped off customer customer4754
# Vehicle 8 dropped off customer customer5714
# Vehicle 2 picked up customer customer5694
# Vehicle 5 picked up customer customer2499
# Vehicle 25 picked up customer customer4323
# Vehicle 28 picked up customer customer2519
# Vehicle 6 dropped off customer customer5849
# Vehicle 29 dropped off customer customer4402
# Vehicle 10 picked up customer customer4128
# Vehicle 11 picked up customer customer5477
# Vehicle 13 picked up customer customer5878
# Vehicle 22 picked up customer customer5055
# Vehicle 2 dropped off customer customer5694
# Vehicle 12 dropped off customer customer4475
# Vehicle 1 picked up customer customer3484
# Vehicle 16 picked up customer customer230
# Vehicle 0 dropped off customer customer2857
# Vehicle 17 dropped off customer customer4253
# Vehicle 19 dropped off customer customer5311
# Vehicle 9 picked up customer customer5683
# Vehicle 12 picked up customer customer5756
# Vehicle 26 picked up customer customer5724
# Vehicle 11 dropped off customer customer5477
# Vehicle 15 dropped off customer customer319
# Vehicle 7 picked up customer customer5499
# Vehicle 11 picked up customer customer5369
# Vehicle 14 picked up customer customer5632
# Vehicle 27 picked up customer customer5013
# Vehicle 13 dropped off customer customer5878
# Vehicle 21 dropped off customer customer483
# Vehicle 23 dropped off customer customer2559
# Vehicle 18 picked up customer customer5737
# Vehicle 19 picked up customer customer2665
# Vehicle 20 picked up customer customer5743
# Vehicle 3 dropped off customer customer3151
# Vehicle 5 dropped off customer customer2499
# Vehicle 7 dropped off customer customer5499
# Vehicle 9 dropped off customer customer5683
# Vehicle 22 dropped off customer customer5055
# Vehicle 24 dropped off customer customer3052
# Vehicle 2 picked up customer customer4983
# Vehicle 4 picked up customer customer3870
# Vehicle 1 dropped off customer customer3484
# Vehicle 12 dropped off customer customer5756
# Vehicle 25 dropped off customer customer4323
# Vehicle 27 dropped off customer customer5013
# Vehicle 6 picked up customer customer2019
# Vehicle 17 picked up customer customer5031
# Vehicle 29 picked up customer customer767
# Vehicle 19 dropped off customer customer2665
# Vehicle 1 picked up customer customer4701
# Vehicle 3 picked up customer customer4962
# Vehicle 8 picked up customer customer5835
# Vehicle 15 picked up customer customer2640
# Vehicle 23 picked up customer customer5042
# Vehicle 6 dropped off customer customer2019
# Vehicle 10 dropped off customer customer4128
# Vehicle 28 dropped off customer customer2519
# Vehicle 0 picked up customer customer3150
# Vehicle 10 picked up customer customer5210
# Vehicle 27 picked up customer customer5246
# Vehicle 2 dropped off customer customer4983
# Vehicle 18 dropped off customer customer5737
# Vehicle 5 picked up customer customer3295
# Vehicle 4 dropped off customer customer3870
# Vehicle 21 picked up customer customer1648
# Vehicle 11 dropped off customer customer5369
# Vehicle 26 dropped off customer customer5724
# Vehicle 22 picked up customer customer2329
# Vehicle 25 picked up customer customer5844
# Vehicle 1 dropped off customer customer4701
# Vehicle 20 dropped off customer customer5743
# Vehicle 24 picked up customer customer3702
# Vehicle 15 dropped off customer customer2640
# Vehicle 17 dropped off customer customer5031
# Vehicle 9 picked up customer customer5592
# Vehicle 3 dropped off customer customer4962
# Vehicle 8 dropped off customer customer5835
# Vehicle 16 dropped off customer customer230
# Vehicle 26 picked up customer customer5840
# Vehicle 14 dropped off customer customer5632
# Vehicle 23 dropped off customer customer5042
# Vehicle 27 dropped off customer customer5246
# Vehicle 28 picked up customer customer3892
# Vehicle 5 dropped off customer customer3295
# Vehicle 10 dropped off customer customer5210
# Vehicle 18 picked up customer customer2138
# Vehicle 25 dropped off customer customer5844
# Vehicle 4 picked up customer customer218
# Vehicle 14 picked up customer customer5824
# Vehicle 21 dropped off customer customer1648
# Vehicle 9 dropped off customer customer5592
# Vehicle 22 dropped off customer customer2329
# Vehicle 0 dropped off customer customer3150
# Vehicle 24 dropped off customer customer3702
# Vehicle 26 dropped off customer customer5840
# Vehicle 29 dropped off customer customer767
# Vehicle 8 picked up customer customer2898
# Vehicle 5 picked up customer customer3985
# Vehicle 18 dropped off customer customer2138
# Vehicle 28 dropped off customer customer3892
# Vehicle 14 dropped off customer customer5824
# Vehicle 8 dropped off customer customer2898
# Vehicle 16 picked up customer customer691
# Vehicle 4 dropped off customer customer218
# Vehicle 5 dropped off customer customer3985
# Vehicle 16 dropped off customer customer691
# average distance 614.0000000000007
#
# average trips 187.54166666666666
